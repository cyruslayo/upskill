# %% [markdown]
#             # Math 05: Linear Algebra - Vectors
#
#             **Level:** 3
#
#             **Learning Objectives**
#             1. Explain the core idea of Linear Algebra - Vectors.
# 2. Trace a small Linear Algebra - Vectors example by hand before coding.
# 3. Implement a compact Python helper for Linear Algebra - Vectors.
# 4. Use tests and sanity checks to verify behavior.

# %%
# Google Colab Setup
# !pip install -q ipywidgets jupyterquiz ipytest plotly sympy networkx pandas numpy matplotlib tqdm

import base64, os, sys
from pathlib import Path

if Path('/content').exists():
    repo_root = Path('/content/upskill')
else:
    repo_root = Path.cwd()

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

try:
    from learning_tools import (
        ProgressStore, Skill, setup_colab, check, code_check,
        short_answer_check, hint_box, mastery_dashboard
    )
except ModuleNotFoundError:
    Path('learning_tools.py').write_bytes(base64.b64decode('...'))
    from learning_tools import (
        ProgressStore, Skill, setup_colab, check, code_check,
        short_answer_check, hint_box, mastery_dashboard
    )

progress_path = setup_colab()
store = ProgressStore(progress_path)
print('Ready for retrieval practice.')

# %%
NOTEBOOK = {
    "id": "math_05_linear_algebra_vectors",
    "filename": "math_05_linear_algebra_vectors.ipynb",
    "title": "Math 05: Linear Algebra - Vectors",
    "level": 3,
    "track": "Math Foundations",
    "objectives": [
        "Explain the core idea of Linear Algebra - Vectors.",
        "Trace a small Linear Algebra - Vectors example by hand before coding.",
        "Implement a compact Python helper for Linear Algebra - Vectors.",
        "Use tests and sanity checks to verify behavior."
    ],
    "prerequisites": [
        "math.math_04_calculus_local_extrema.implementation",
        "math.math_04_calculus_local_extrema.transfer"
    ],
    "skills_taught": [
        "math.math_05_linear_algebra_vectors.retrieval",
        "math.math_05_linear_algebra_vectors.implementation",
        "math.math_05_linear_algebra_vectors.transfer"
    ],
    "skills_practiced": [
        "math.math_04_calculus_local_extrema.implementation",
        "math.math_04_calculus_local_extrema.transfer"
    ],
    "next_notebook": "math_06_linear_algebra_matrices.ipynb"
}

SKILLS = [
    {
        "id": "math.math_05_linear_algebra_vectors.retrieval",
        "title": "Retrieval for Math 05: Linear Algebra - Vectors",
        "notebook": "math_05_linear_algebra_vectors.ipynb",
        "level": 3,
        "prerequisites": [
            "math.math_04_calculus_local_extrema.implementation",
            "math.math_04_calculus_local_extrema.transfer"
        ],
        "tags": [
            "math-foundations",
            "math_05_linear_algebra_vectors"
        ]
    },
    {
        "id": "math.math_05_linear_algebra_vectors.implementation",
        "title": "Implementation for Math 05: Linear Algebra - Vectors",
        "notebook": "math_05_linear_algebra_vectors.ipynb",
        "level": 3,
        "prerequisites": [
            "math.math_04_calculus_local_extrema.implementation",
            "math.math_04_calculus_local_extrema.transfer"
        ],
        "tags": [
            "math-foundations",
            "math_05_linear_algebra_vectors"
        ]
    },
    {
        "id": "math.math_05_linear_algebra_vectors.transfer",
        "title": "Transfer for Math 05: Linear Algebra - Vectors",
        "notebook": "math_05_linear_algebra_vectors.ipynb",
        "level": 3,
        "prerequisites": [
            "math.math_04_calculus_local_extrema.implementation",
            "math.math_04_calculus_local_extrema.transfer"
        ],
        "tags": [
            "math-foundations",
            "math_05_linear_algebra_vectors"
        ]
    }
]

# %% [markdown]
# ## Before You Learn: Pull From Memory
# Answer before reading. Retrieval is useful even when it feels effortful.

# %% [markdown]
# **Recall 1.** What is the first thing to identify before implementing an algorithmic or mathematical procedure?

# %%
answer = ''
short_answer_check(
    'retrieval_1',
    answer,
    ['state', 'the state', 'inputs', 'representation'],
    skill_id='math.math_05_linear_algebra_vectors.retrieval',
    confidence=3,
    store=store,
)

# %% [markdown]
# **Recall 2.** Why should you test on a tiny example before a large one?

# %%
answer = ''
short_answer_check(
    'retrieval_2',
    answer,
    ['sanity check', 'debugging', 'verify', 'catch errors', 'easier to inspect'],
    skill_id='math.math_05_linear_algebra_vectors.retrieval',
    confidence=3,
    store=store,
)

# %% [markdown]
# ## Micro-Lesson
# Linear Algebra - Vectors is best learned as a loop between representation, procedure, and verification. First name the state you are tracking, then describe the update rule, then test the rule on a small case where the answer can be checked by hand.

# %% [markdown]
# ## Worked Example
# For a small Linear Algebra - Vectors problem, write the inputs, predict one step manually, and only then translate the step into Python. This keeps the code connected to the mathematics instead of becoming a memorized recipe.

# %% [markdown]
# ## Faded Example
# When solving a new Linear Algebra - Vectors task, fill these blanks: state = ____, update = ____, stopping condition = ____, check = ____.

# %% [markdown]
# ## Independent Practice
# Use the scaffold, run the checks, then revise until the behavior is correct.

# %% [markdown]
# ### Summarize the Method
#
# Implement `lesson_summary()` so it returns the topic and three habits used in Linear Algebra - Vectors.

# %%
def lesson_summary():
    topic = ''
    habits = []
    # student scaffold: fill topic and three habits
    return {'topic': topic, 'habits': habits}

# %%
summary = lesson_summary()
check('topic recorded', summary['topic'], 'Linear Algebra - Vectors', skill_id=SKILLS[1]['id'], store=store)
check('three habits', len(summary['habits']), 3, skill_id=SKILLS[1]['id'], store=store)

# %%
hint_box(
    'Hints: Summarize the Method',
    ['Name the notebook topic exactly.', 'Use three short action phrases.', 'Return a dictionary with keys `topic` and `habits`.'],
    unlock=False,
)

# %% [markdown]
# ## Transfer Challenge
# Adapt the same representation-update-check pattern to a fresh Linear Algebra - Vectors example that is not shown in this notebook.

# %% [markdown]
# ## End-of-Notebook Review
# Retrieve the key ideas once more and inspect the review dashboard.

# %%
mastery_dashboard(store=store, skills=SKILLS, next_notebook=NOTEBOOK.get('next_notebook'))
